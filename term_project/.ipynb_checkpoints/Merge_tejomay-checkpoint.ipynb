# %%
# 1. Load data
import pandas as pd
from os import listdir, getcwd

# %%
gdelt = pd.read_csv('gdelt_dataframe.csv')

gdelt.head()
# Out:
#   Actor2Geo_CountryCode  Year  GoldsteinScale   AvgTone  QuadClass  \
# 0                    AA  2006        0.000000  4.547804   1.000000
# 1                    AA  2014        3.866667  0.165841   1.333333
# 2                    AA  2015        0.400000 -5.541607   1.500000
# 3                    AA  2018       -4.200000 -8.310443   3.600000
# 4                    AA  2019        2.400000  1.240730   1.000000
#
#    NumMentions
# 0     4.000000
# 1     9.333333
# 2     7.500000
# 3     9.200000
# 4     5.333333

# %%
# (b) Read in asylum seekers
seekers = pd.read_csv(getcwd() + '/Target_Variable/Asylum_seekers_per_country_per_year_w_prev_year.csv')
seekers = seekers.drop('Unnamed: 0', axis = 1)
seekers.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-b8ca5d3bd004> in <module>
#       1 # (b) Read in asylum seekers
# ----> 2 seekers = pd.read_csv(getcwd() + '/Target_Variable/Asylum_seekers_per_country_per_year_w_prev_year.csv')
#       3 seekers = seekers.drop('Unnamed: 0', axis = 1)
#       4 seekers.head()
#
# ~/workspace/.venv/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/workspace/.venv/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/workspace/.venv/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/workspace/.venv/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~/workspace/.venv/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'/Users/gmholden/workspace/dsga1001/term_project/Target_Variable/Asylum_seekers_per_country_per_year_w_prev_year.csv' does not exist: b'/Users/gmholden/workspace/dsga1001/term_project/Target_Variable/Asylum_seekers_per_country_per_year_w_prev_year.csv'

# %%
# (c) Read in populations
pop = pd.read_csv(getcwd() + '/initial_analysis/populations.csv', skiprows = [i for i in range(0, 3)])
pop.head()
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996973.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5454933.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL    13411.0
#
#         1961       1962       1963       1964       1965  ...        2010  \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0  ...    101669.0
# 1  9169410.0  9351441.0  9543205.0  9744781.0  9956320.0  ...  29185507.0
# 2  5531472.0  5608539.0  5679458.0  5735044.0  5770570.0  ...  23356246.0
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0  ...   2913021.0
# 4    14375.0    15370.0    16412.0    17469.0    18549.0  ...     84449.0
#
#          2011        2012        2013        2014        2015        2016  \
# 0    102046.0    102560.0    103159.0    103774.0    104341.0    104872.0
# 1  30117413.0  31161376.0  32269589.0  33370794.0  34413603.0  35383128.0
# 2  24220661.0  25107931.0  26015780.0  26941779.0  27884381.0  28842484.0
# 3   2905195.0   2900401.0   2895092.0   2889104.0   2880703.0   2876101.0
# 4     83747.0     82427.0     80774.0     79213.0     78011.0     77297.0
#
#          2017        2018  Unnamed: 63
# 0    105366.0    105845.0          NaN
# 1  36296400.0  37172386.0          NaN
# 2  29816748.0  30809762.0          NaN
# 3   2873457.0   2866376.0          NaN
# 4     77001.0     77006.0          NaN
#
# [5 rows x 64 columns]

# %%
# (d) Read in ISO codes
iso = pd.read_csv(getcwd() + '/Target_Variable/ISO_codes.csv')
iso.head()
# Out:
#   English short name        French short name Alpha-2 code Alpha-3 code  \
# 0        Afghanistan         Afghanistan (l')           AF          AFG
# 1            Albania             Albanie (l')           AL          ALB
# 2            Algeria             Algérie (l')           DZ          DZA
# 3     American Samoa  Samoa américaines (les)           AS          ASM
# 4            Andorra             Andorre (l')           AD          AND
#
#    Numeric
# 0        4
# 1        8
# 2       12
# 3       16
# 4       20

# %%
# 2. Merge
# (a) seekers with iso
seekers_iso = seekers.merge(iso, left_on = 'Origin', right_on = 'English short name', validate = 'many_to_one', indicator = True)

print("Check seekers-iso merge:")
print(seekers_iso._merge.value_counts())

seekers_iso = seekers_iso.drop('_merge', axis = 1)
# Out:
# Check seekers-iso merge:
# both          3141
# right_only       0
# left_only        0
# Name: _merge, dtype: int64

# %%
# (b) merge seekers_iso with pop
seekers_iso_pop = seekers_iso.merge(pop, left_on = 'Alpha-3 code', right_on = 'Country Code', validate = 'many_to_one', indicator = True)

print("Check seekers-iso-pop merge:")
print(seekers_iso_pop._merge.value_counts())

seekers_iso_pop = seekers_iso_pop.drop('_merge', axis = 1)
# Out:
# Check seekers-iso-pop merge:
# both          3102
# right_only       0
# left_only        0
# Name: _merge, dtype: int64

# %%
# (b) merge seekers_iso_pop with gdelt
seekers_iso_pop.columns
seekers_iso_pop_gdelt = seekers_iso.merge(gdelt, left_on = 'Alpha-2 code', right_on = 'Actor2Geo_CountryCode', validate = 'many_to_many', indicator = True)

print("Check seekers-iso-pop-gdelt merge:")
print(seekers_iso_pop_gdelt._merge.value_counts())

seekers_iso_pop_gdelt = seekers_iso_pop_gdelt.drop('_merge', axis = 1)
# Out:
# Check seekers-iso-pop-gdelt merge:
# both          1276699
# right_only          0
# left_only           0
# Name: _merge, dtype: int64

# %%
# 3. Export
seekers_iso_pop_gdelt.to_csv("merged_seekers_iso_pop_gdelt.csv")
